# %%
import numpy as np
import pandas as pd

# %%
students = pd.DataFrame([
    {
        "id": "100001",
        "student": "Ada Lovelace",
        "coffee_preference": "light",
        "course": "web development",
        "grades": [70, 91, 82, 71],
        "pets": [{"species": "horse", "age": 8}],
    },
    {
        "id": "100002",
        "student": "Thomas Bayes",
        "coffee_preference": "medium",
        "course": "data science",
        "grades": [75, 73, 86, 100],
        "pets": [],
    },
    {
        "id": "100003",
        "student": "Marie Curie",
        "coffee_preference": "light",
        "course": "web development",
        "grades": [70, 89, 69, 65],
        "pets": [{"species": "cat", "age": 0}],
    },
    {
        "id": "100004",
        "student": "Grace Hopper",
        "coffee_preference": "dark",
        "course": "data science",
        "grades": [73, 66, 83, 92],
        "pets": [{"species": "dog", "age": 4}, {"species": "cat", "age": 4}],
    },
    {
        "id": "100005",
        "student": "Alan Turing",
        "coffee_preference": "dark",
        "course": "web development",
        "grades": [78, 98, 85, 65],
        "pets": [
            {"species": "horse", "age": 6},
            {"species": "horse", "age": 7},
            {"species": "dog", "age": 5},
        ],
    },
    {
        "id": "100006",
        "student": "Rosalind Franklin",
        "coffee_preference": "dark",
        "course": "data science",
        "grades": [76, 70, 96, 81],
        "pets": [],
    },
    {
        "id": "100007",
        "student": "Elizabeth Blackwell",
        "coffee_preference": "dark",
        "course": "web development",
        "grades": [69, 94, 89, 86],
        "pets": [{"species": "cat", "age": 10}],
    },
    {
        "id": "100008",
        "student": "Rene Descartes",
        "coffee_preference": "medium",
        "course": "data science",
        "grades": [87, 79, 90, 99],
        "pets": [{"species": "cat", "age": 10}, {"species": "cat", "age": 8}],
    },
    {
        "id": "100009",
        "student": "Ahmed Zewail",
        "coffee_preference": "medium",
        "course": "data science",
        "grades": [74, 99, 93, 89],
        "pets": [{"species": "cat", "age": 0}, {"species": "cat", "age": 0}],
    },
    {
        "id": "100010",
        "student": "Chien-Shiung Wu",
        "coffee_preference": "medium",
        "course": "web development",
        "grades": [82, 92, 91, 65],
        "pets": [{"species": "cat", "age": 8}],
    },
    {
        "id": "100011",
        "student": "William Sanford Nye",
        "coffee_preference": "dark",
        "course": "data science",
        "grades": [70, 92, 65, 99],
        "pets": [{"species": "cat", "age": 8}, {"species": "cat", "age": 5}],
    },
    {
        "id": "100012",
        "student": "Carl Sagan",
        "coffee_preference": "medium",
        "course": "data science",
        "grades": [100, 86, 91, 87],
        "pets": [{"species": "cat", "age": 10}],
    },
    {
        "id": "100013",
        "student": "Jane Goodall",
        "coffee_preference": "light",
        "course": "web development",
        "grades": [80, 70, 68, 98],
        "pets": [{"species": "horse", "age": 4}],
    },
    {
        "id": "100014",
        "student": "Richard Feynman",
        "coffee_preference": "medium",
        "course": "web development",
        "grades": [73, 99, 86, 98],
        "pets": [{"species": "dog", "age": 6}],
    },
])

# %%
type(students)
# Out:
# pandas.core.frame.DataFrame

# %%
#1 How many students are there?
student_count = len(students)
print(student_count)
# Out:
# 14

# %%
students.count()
# Out:
# id                   14
# student              14
# coffee_preference    14
# course               14
# grades               14
# pets                 14
# dtype: int64

# %%
#2a How many students prefer light coffee?
df = pd.DataFrame(students)
df
# Out:
#         id              student coffee_preference           course  \
# 0   100001         Ada Lovelace             light  web development
# 1   100002         Thomas Bayes            medium     data science
# 2   100003          Marie Curie             light  web development
# 3   100004         Grace Hopper              dark     data science
# 4   100005          Alan Turing              dark  web development
# 5   100006    Rosalind Franklin              dark     data science
# 6   100007  Elizabeth Blackwell              dark  web development
# 7   100008       Rene Descartes            medium     data science
# 8   100009         Ahmed Zewail            medium     data science
# 9   100010      Chien-Shiung Wu            medium  web development
# 10  100011  William Sanford Nye              dark     data science
# 11  100012           Carl Sagan            medium     data science
# 12  100013         Jane Goodall             light  web development
# 13  100014      Richard Feynman            medium  web development
#
#                grades                                               pets
# 0    [70, 91, 82, 71]                   [{'species': 'horse', 'age': 8}]
# 1   [75, 73, 86, 100]                                                 []
# 2    [70, 89, 69, 65]                     [{'species': 'cat', 'age': 0}]
# 3    [73, 66, 83, 92]  [{'species': 'dog', 'age': 4}, {'species': 'ca...
# 4    [78, 98, 85, 65]  [{'species': 'horse', 'age': 6}, {'species': '...
# 5    [76, 70, 96, 81]                                                 []
# 6    [69, 94, 89, 86]                    [{'species': 'cat', 'age': 10}]
# 7    [87, 79, 90, 99]  [{'species': 'cat', 'age': 10}, {'species': 'c...
# 8    [74, 99, 93, 89]  [{'species': 'cat', 'age': 0}, {'species': 'ca...
# 9    [82, 92, 91, 65]                     [{'species': 'cat', 'age': 8}]
# 10   [70, 92, 65, 99]  [{'species': 'cat', 'age': 8}, {'species': 'ca...
# 11  [100, 86, 91, 87]                    [{'species': 'cat', 'age': 10}]
# 12   [80, 70, 68, 98]                   [{'species': 'horse', 'age': 4}]
# 13   [73, 99, 86, 98]                     [{'species': 'dog', 'age': 6}]

# %%
sum(df.coffee_preference == 'light')
# Out:
# 3

# %%
#2b For each coffee type?...
df.groupby('coffee_preference').count().student
# Out:
# coffee_preference
# dark      5
# light     3
# medium    6
# Name: student, dtype: int64

# %%
#3 How many types of pets?
df.groupby('pets').count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/x6/9q2vjsz90nx_0lgx5gr8g33w0000gn/T/ipykernel_36353/806209997.py in <module>
#       1 #3 How many types of pets?
# ----> 2 df.groupby('pets').count()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/generic.py in count(self)
#    1728         """
#    1729         data = self._get_data_to_aggregate()
# -> 1730         ids, _, ngroups = self.grouper.group_info
#    1731         mask = ids != -1
#    1732
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/ops.py in group_info(self)
#     898     @cache_readonly
#     899     def group_info(self):
# --> 900         comp_ids, obs_group_ids = self._get_compressed_codes()
#     901
#     902         ngroups = len(obs_group_ids)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/ops.py in _get_compressed_codes(self)
#     922
#     923         ping = self.groupings[0]
# --> 924         return ping.codes, np.arange(len(ping.group_index))
#     925
#     926     @final
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/grouper.py in codes(self)
#     610             return self._codes
#     611
# --> 612         return self._codes_and_uniques[0]
#     613
#     614     @cache_readonly
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/grouper.py in _codes_and_uniques(self)
#     668             else:
#     669                 na_sentinel = -1
# --> 670             codes, uniques = algorithms.factorize(
#     671                 self.grouping_vector, sort=self._sort, na_sentinel=na_sentinel
#     672             )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/algorithms.py in factorize(values, sort, na_sentinel, size_hint)
#     759             na_value = None
#     760
# --> 761         codes, uniques = factorize_array(
#     762             values, na_sentinel=na_sentinel, size_hint=size_hint, na_value=na_value
#     763         )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/algorithms.py in factorize_array(values, na_sentinel, size_hint, na_value, mask)
#     561
#     562     table = hash_klass(size_hint or len(values))
# --> 563     uniques, codes = table.factorize(
#     564         values, na_sentinel=na_sentinel, na_value=na_value, mask=mask
#     565     )
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'
