# %%
import matplotlib.pyplot as plt
import numpy as np
import math as m

# %%
#1
plt.figure(figsize= (7,5))
x = range(-100, 101)
y =[(n**2 - n + 2) for n in x]
plt.plot(x,y)
plt.annotate('Intersection', xy=(0,0))
plt.show()

# %%
#2
plt.figure(figsize= (7,5))
n = range(0, 200)
def f(x):
    squared = m.sqrt(x)
    return squared
y2 = [f(x) for x in n] 
plt.plot(n,y)
plt.show()

# %%
plt.figure(figsize= (7,5))
n = range(0, 200)
def f(x):
    trip = x**3
    return trip
y3 = [f(x) for x in n] 
plt.plot(n,y)
plt.show()

# %%
plt.figure(figsize= (7,5))
n = range(0, 200)
def f(x):
    power = 2^x
    return power
y4 = [f(x) for x in n] 
plt.plot(n,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/x6/9q2vjsz90nx_0lgx5gr8g33w0000gn/T/ipykernel_15375/4237001036.py in <module>
#       5     return power
#       6 y4 = [f(x) for x in n]
# ----> 7 plt.plot(n,y)
#       8 plt.show()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
#    1604         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1605         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606         for line in lines:
#    1607             self.add_line(line)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     313                 this += args[0],
#     314                 args = args[1:]
# --> 315             yield from self._plot_args(this, kwargs)
#     316
#     317     def get_next_color(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     499
#     500         if x.shape[0] != y.shape[0]:
# --> 501             raise ValueError(f"x and y must have same first dimension, but "
#     502                              f"have shapes {x.shape} and {y.shape}")
#     503         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (200,) and (201,)

# %%
plt.figure(figsize= (7,5))
n = range(0, 200)
def f(x):
    fig = 1/(x + 1)
    return fig
y = [f(x) for x in n] 
plt.plot(n,y)
plt.show()

# %%
#3
n_rows = 1
n_cols = 4

plt.subplot(n_rows, n_cols, 1)
n = range(0, 100)
def f(x):
    squared = m.sqrt(x)
    return squared
y = [f(x) for x in n] 
plt.plot(n,y)
plt.title('sqrt(x)')

plt.subplot(n_rows, n_cols, 2)
n = range(0, 100)
def f(x):
    trip = x**3
    return trip
y = [f(x) for x in n] 
plt.plot(n,y)
plt.xlim(0, 100)
plt.ylim(0, 500000)
plt.title('x^3')

plt.subplot(n_rows, n_cols, 3)
n = range(0, 100)
def f(x):
    power = 2^x
    return power
y = [f(x) for x in n] 
plt.plot(n,y)
plt.title('2^x')

plt.subplot(n_rows, n_cols, 4)
n = range(0, 100)
def f(x):
    fig = 1/(x + 1)
    return fig
y = [f(x) for x in n] 
plt.plot(n,y)
plt.title('1/(x + 1)')
# Out:
# Text(0.5, 1.0, '1/(x + 1)')

# %%
#4

# %%
plt.figure(figsize(10, 10))

y1 = [f(x) for x in n]
y2 =
# Out:
#   File "/var/folders/x6/9q2vjsz90nx_0lgx5gr8g33w0000gn/T/ipykernel_15375/2182656989.py", line 5
#     def f(x):
#     ^
# SyntaxError: invalid syntax
